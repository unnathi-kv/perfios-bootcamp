# %%
path='c:\josh\name\text.file'
print(path)
# Out:
# c:\josh
# ame	ext.file

# %%
path='c:\josh\name\text.file'
path
# Out:
# 'c:\\josh\name\text.file'

# %%
path='c:\\josh\\name\\text.file'
print(path)
# Out:
# c:\josh\name\text.file
# 'c:\\josh\\name\\text.file'

# %%
path=r'c:\josh\name\text.file'
print(path)
# Out:
# c:\josh\name\text.file
# 'c:\\josh\\name\\text.file'

# %%
name = "Josh"
print(name.swapcase())
# Out:
# jOSH

# %%
print(dir(str))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
help(str.center)
# Out:
# Help on method_descriptor:
#
# center(self, width, fillchar=' ', /)
#     Return a centered string of length width.
#
#     Padding is done using the specified fill character (default is a space).

# %%
name=" ********__________********** "
name.center(100,'+')
# Out:
# '+++++++++++++++++++++++++++++++++++ ********__________********** +++++++++++++++++++++++++++++++++++'

# %%
name="joshua.hong"
name.split("h")
# Out:
# ['jos', 'ua.', 'ong']

# %%
str1="Hello~~~                      "
str1.rstrip()
# Out:
# 'Hello~~~'

# %%
str2="This is life$@"
s2=str2.rstrip('$@')
s2
# Out:
# 'This is life'

# %% [markdown]
# #### Can strings be added without using the + operator

# %%
"jo"   "sh" "  ua"  # this is only possible when you are using literals
# Out:
# 'josh  ua'

# %%
a="jo"
b="shua"
a+b
# Out:
# 'joshua'

# %%
help('FORMATTING')
# Out:
# Format String Syntax
# ********************
#
# The "str.format()" method and the "Formatter" class share the same
# syntax for format strings (although in the case of "Formatter",
# subclasses can define their own format string syntax).  The syntax is
# related to that of formatted string literals, but there are
# differences.
#
# Format strings contain “replacement fields” surrounded by curly braces
# "{}". Anything that is not contained in braces is considered literal
# text, which is copied unchanged to the output.  If you need to include
# a brace character in the literal text, it can be escaped by doubling:
# "{{" and "}}".
#
# The grammar for a replacement field is as follows:
#
#       replacement_field ::= "{" [field_name] ["!" conversion] [":" format_spec] "}"
#       field_name        ::= arg_name ("." attribute_name | "[" element_index "]")*
#       arg_name          ::= [identifier | digit+]
#       attribute_name    ::= identifier
# ...

# %%
name= "jos"
f'{name: >30}'
# Out:
# '                           jos'

# %%
print("josh","hong","vernon","chwe",sep='*',end='&')
# Out:
# josh*hong*vernon*chwe&

# %%
type(print)
# Out:
# builtin_function_or_method

# %%
def print(*args):
    return "Hello Python"
print
# Out:
# <function __main__.print(*args)>

# %%
print(1,1)
# Out:
# 'Hello Python'

# %%
print("Hello black mamba")
# Out:
# 'Hello Python'

# %%
del print

# %%
print("hello python and method")...
# Out:
# hello python and method

# %%
del print
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_28670/1941634850.py in <module>
# ----> 1 del print
#
# NameError: name 'print' is not defined

# %%
name
# Out:
# 'jos'

# %%
globals() # return history of the file in dict
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "path='c:\\josh\\name\\text.file'\npath",
#   "path='c:\\josh\\name\\text.file'\nprint(path)",
#   "path='c:\\\\josh\\\\name\\\\text.file'\nprint(path)",
#   "path='c:\\josh\\name\\text.file'\npath",
#   "path=r'c:\\josh\\name\\text.file'\nprint(path)",
#   "path='c:\\\\josh\\\\name\\\\text.file'\nprint(path)\npath",
#   "path=r'c:\\josh\\name\\text.file'\nprint(path)\npath",
#   'name="joshua"\nname.touppercase()',
#   'name="joshua"\nname.uppercase()',
#   'print(dir(string))',
#   'print(dir(String))',
#   'name = "josh"\nprint(name.swapcase())',
#   'name = "Josh"\nprint(name.swapcase())',
#   'print(dir(str))',
#   'name.center',
#   'hemlp(str.center)',
#   'help(str.center)',
# ...

# %%
globals()['name']
# Out:
# 'jos'

# %%
help(globals())
# Out:
# Help on dict object:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if the dictionary has the specified key, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
# ...
